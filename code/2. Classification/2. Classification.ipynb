# %% [markdown]
# Reference: https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %% [markdown]
# # Purpose
# 研究客戶流失(churn)的相關議題
#
# (1) 客戶離開組織的可能性有多大？
# (2) 客戶流失的關鍵指標是什麼？
# (3) 可以根據結果實施哪些保留策略以減少潛在客戶流失？

# %% [markdown]
# # 1. import data

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\student\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (1.16.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# conda install -c anaconda py-xgboost

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1-1 Restart the session

# %%
try:
    from IPython import get_ipython
    get_ipython().magic('clear')
    get_ipython().magic('reset -f')
except:
    pass

# %% [markdown]
# ## 1-2 Import relevant libraries

# %%
#Standard libraries for data analysis:  
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm, skew
from scipy import stats
import statsmodels.api as sm

import seaborn as sns # For creating plots
sns.set_style('darkgrid')

# %%
# sklearn modules for data preprocessing:
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#sklearn modules for Model Selection:
from sklearn import svm, tree, linear_model, neighbors
from sklearn import naive_bayes, ensemble, discriminant_analysis, gaussian_process
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#sklearn modules for Model Evaluation & Improvement:   
from sklearn.metrics import confusion_matrix, accuracy_score 
from sklearn.metrics import f1_score, precision_score, recall_score, fbeta_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import KFold
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
from sklearn.metrics import classification_report, precision_recall_curve
from sklearn.metrics import auc, roc_auc_score, roc_curve
from sklearn.metrics import make_scorer, recall_score, log_loss
from sklearn.metrics import average_precision_score

# %%
#Standard libraries for data visualization:
import seaborn as sn
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib 
# %matplotlib inline
color = sn.color_palette()

import matplotlib.ticker as mtick
from IPython.display import display
pd.options.display.max_columns = None
from pandas.plotting import scatter_matrix
from sklearn.metrics import roc_curve

# %%
#Miscellaneous Utilitiy Libraries:
import random
import os
import re
import sys
import timeit
import string
import time
from datetime import datetime
from time import time
from dateutil.parser import parse
import joblib

# %% [markdown]
# ## 1-3 Read data:

# %%
dataset = pd.read_csv('customer_churn_data.csv')
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %% [markdown]
# ## 1-4 Evaluate data structure

# %% [markdown]
# 0   customerID
# 1   gender: 男性或女性
# 2   SeniorCitizen: 客戶是否是老年人 (1, 0)
# 3   Partner: 客戶是否有合作夥伴 (Yes, No)
# 4   Dependents: 客戶是否有家屬 (Yes, No)
# 5   tenure: 客戶停留的月數
# 6   PhoneService: 客戶是否有電話服務 (Yes, No)
# 7   MultipleLines: 客戶是否有多條線路 (Yes, No, No phone service)
# 8   InternetService: 客戶的互聯網服務提供商 (DSL, Fiber optic, No)
# 9   OnlineSecurity: 客戶是否有 online security (Yes, No, No internet service)
# 10  OnlineBackup: 客戶是否有在線備份 (Yes, No, No internet service)
# 11  DeviceProtection: 客戶是否有設備保護 (Yes, No, No internet service)
# 12  TechSupport: 客戶是否有技術支持 (Yes, No, No internet service)
# 13  StreamingTV: 客戶是否有 streaming TV (Yes, No, No internet service)
# 14  StreamingMovies: 客戶是否有 streaming movies (Yes, No, No internet service)
# 15  Contract: 客戶的合約期限 (Month-to-month, One year, Two year)
# 16  PaperlessBilling: 客戶是否有無紙化計費 (Yes, No)
# 17  PaymentMethod: 客戶的付款方式 (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# 18  MonthlyCharges: 每月向客戶收取的金額
# 19  TotalCharges: 向客戶收取的總金額
# 20  Churn: 客戶是否流失 (Yes or No)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
dataset['SeniorCitizen'] = dataset['SeniorCitizen'].astype(object)
dataset['TotalCharges'] = pd.to_numeric(dataset['TotalCharges'], errors='coerce')
dataset.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %% [markdown]
# ### <span style="color:#3498DB">Point: 請就下列敘述性統計進行分析</span>

# %%
dataset.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# 客戶平均停留 32 個月，每月支付 64 美元，共支付2,283美元。 但是，不同客戶有不同的合約。

# %%
# 不同的合約期間，停留月數和付費情況是否有差異
dataset.groupby(['Contract'], as_index=True).mean()[['tenure', 'MonthlyCharges', 'TotalCharges']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
#     895     res = extract_result(res)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2461, in GroupBy.mean.<locals>.<lambda>(x)
#    2458 else:
#    2459     result = self._cython_agg_general(
#    2460         "mean",
# -> 2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '7590-VHVEG3668-QPYBK9237-HQITU9305-CDSKC1452-KIOVK6713-OKOMC7892-POOKP9763-GRSKD0280-XJGEX5129-JLPIS4190-MFLUW4183-MYFRB8779-QRDMV1066-JKSGK6322-HRPFA6865-JZNKO6467-CHFZW8665-UTDHZ8773-HHUOZ4929-XIHVW7310-EGVHZ3413-BMNZE6047-YHPVI6572-ADKRS5380-WJKOV8168-UQWWF4080-IIARD3714-NTNFO5948-UJZLF7760-OYPDY8012-SOUDQ9420-LOJKX6575-SUVOI7495-OOKFY1658-BYGOY0434-CSFON1215-FIGMP5698-BQJOH5122-CYFXA7410-OIEDU2273-QCKXA5630-AHZIL5590-ZSKRV0191-ZHSKZ5919-TMRGD8108-UXRQN9191-MYQKX9919-YLNNG4445-ZJNMU3016-KSVCP4767-HZZHQ2424-WVHPL6067-NGCEU8637-XJIVR0278-YXOOG4598-XLKNJ6380-ARCEH3679-XASPY6180-YBIQI0486-HECZI5712-AHQNN4846-WHAFZ3071-VBYPO5299-RULOA9445-ZUEQE2928-HLDBA0404-SWRVG6497-TILVL7219-TLZHO4412-YLTKF3930-ZGWVE2876-GZYZC6207-WIOLX3091-FYHKI2372-HWUHI7850-VWJUU0390-DCFDQ4080-OGPJL2135-RXIHG3466-BYAVD3780-YVMFA3874-EQOEP3077-RSNTJ6551-GNYDG9167-APMXZ8992-VONJD0867-MKZVY4482-EWFMI3376-BMGFE3445-HXXGF1159-WFSGR1875-QIVME1744-JHKYS2656-FMOKZ2070-FNEXE5947-SGKCL6317-YPKDH6582-OIVSP9367-WXLCH1918-ZBFQJ1024-GUALD4827-USJHP8167-GJLRN8017-UVSZU2472-OVKUP2604-IJPDU6168-YBYNP3645-DEYGF8544-GOQSH7018-WBJNK9142-KZXOP1285-OKIPP7825-ECJRF7841-TZDMQ4195-NZGTA2504-DSHIH0699-NDKJM6496-JDSSB9408-SSNVZ0742-MOABM2232-DMLXU4811-JBUVU3316-UWXUY8937-RDTHP1984-GPTEH1251-KRREG9903-LYSAB0094-OIFMO9058-HRZSV4522-AKYLR0221-WMXNQ9947-OTFQU0322-YINQP4629-NRXKX9514-JDSKI3675-YDUPJ4959-JOSRX5046-NUHWD7273-TEFQD3606-TWKGI7529-ZDFXI3197-ARFOY4385-GZQXV6366-ZGQGL4716-HHKQH5940-AHUHD6432-TWQLB4484-GLZOU3179-GBRWV8645-KWHJO4130-MZLCC0314-TKOSI8229-MYEJZ2080-SRCDE9577-WJVCQ9512-UIBFX3808-HFKDE5583-SXDAG3488-PGMQJ3580-REOAC7534-BFESC4847-TAJYI1563-IWQEX8203-XJZRC6851-WEFYX2985-JUUBZ6390-DSAZX8098-LLAZX8266-VBFQL2240-HSJQD0265-EDXBD3167-SNQPL1098-TDVUQ7277-OZCGZ2799-ARNLO7563-BIUPC2840-XANRC6745-JEFZB8705-WZCYL4983-CLMLV5701-YVSVF5804-LEPIM5697-GOMBF2739-CACDQ0122-OAHPZ2868-SNELZ7982-VCELR1343-EHPYB6035-BXTTY7520-HQWJU0021-IKXGC2034-GDRCN6243-OZGFH4115-NZRKS0219-YTZUE0623-IIHUG4572-DVCGN3351-NGXYI9057-MSWCO9294-TDIPC3583-KRKMD1010-DIAUQ9069-LGEUL7302-ZHMHP0259-GBZSH6862-CQUMB6158-HDPXZ9601-BRXPO6905-NIQIN5167-ZFFMM4895-TMWIR0533-BNWKF8782-LKFPK5522-JBWMO3597-MVHJT9774-NRNAU0224-RLWWD9967-ATRFS3951-NJCVI0177-PXBAT6599-CEBNN2519-ERQOJ0979-PHULV0111-KLBQG4800-VHZKI7989-CHGTL0334-GDDSO5233-AOZUF5973-EJGDP1996-DBMUS7916-VCCPB0578-SKVMF5564-NEMQO2233-FAGXV5605-IYGFG8111-BKVDS2055-SIFSS8734-DKSTZ4360-PNRQB9063-ZGTUY2181-UAESM2957-LOLHO2320-SLKMB5886-VLQVU3577-AMVUX0771-WLCLA5628-RKIFK2937-FTHUR1910-FMXJM7752-XUSCI4110-PFEUZ5168-MSWXT5760-WRAHC8847-GEOOQ0256-LTHVJ8313-NDOIA4237-CLSMM1452-VOQCH4719-UMSIY6614-VBEGU0880-TKATG3811-VBYBZ4640-UHDOS3583-EKAPL1304-BCCFO4104-PVRPS9399-APLBT2359-KMGLI3780-DDGSE4431-EDMIQ0306-JAELE6227-HWPWX0447-BEMNG4612-SSVHJ5949-XIKAE9094-AZPHK8372-JUXUI6778-YSNIH0388-EOPEX6579-JPICP4134-BSXLX6235-VDHOM7783-YKGDV7803-XOCCZ5609-CEBID8981-FJGLA7218-HKQFK4636-QRJKY1135-LMECX8535-SFUTN5956-VKDTT8677-HDZEE2475-MROZF9412-GHEEC6705-LXORM0257-ZESQC7531-GQHME4109-CYRBD0913-XWSCN6825-UYPFK8397-MVTAZ4234-XTNEA9282-IZGQK5348-CAGXB0621-HJWXJ2782-LFZVW2866-IKBTM1342-JPNKI2817-NTQDO6986-IJDHX8138-EALND5301-GAUUY2654-VBVPB2501-XWWTZ3716-UVSPD7343-EOBEU3701-SFMUH7319-VENRZ0939-YAPAF6030-REHUX8270-RKSAP6522-YRBXD2640-LYMOV1218-VKFPE3627-FHKBK2865-TCHJW1423-BMPBQ2393-DIVAI5192-EBGOV0215-BQKGS9244-ZVAPM0719-SYFRB5172-MIGPM5839-SUYVZ3419-SNJJD6543-CPZMK4765-OXPPD9396-ZSFLL6464-KEXXH5240-CAOYT4059-IIEBK4881-JVQOD1009-IRMNA3003-CMDUU5016-IBERQ4554-YGZIH5099-BAILX9931-KGHOA7207-RMRDB0195-IESCP4580-TMHJU0970-ETWGE8404-VLQFB1626-ERCMM0887-HJGAR5644-PDMZC3509-GWQGF9576-ANLXO2024-BASKD1140-UKVZG4160-AMJTL5183-SNMJQ2085-JVGAD5650-VDUDS8095-WANWK3030-ZKIWL2800-VEQXM7538-GWHML5533-RJFTJ3859-CVCET3276-HDUEG9092-GDZKO0823-HSCDJ0822-GAVAP5760-IFJOZ2826-UWHIS1448-PWKYE4957-TREIR8040-MNRTF1536-HBSWP0067-DKWBL5076-YVXCM8262-COGGB2276-YDAVZ2480-JZOSN5896-NPFWW9450-TRJUU1766-GKNMI6942-LBFDP1456-TWCGB7133-VBDCG3014-WJKSM3347-YJZZE1029-QFBEN7929-DMBCV5433-KYGHE557 ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 不同的合約期間，停留月數和付費情況是否有差異
# ----> 2 dataset.groupby(['Contract'], as_index=True).mean()[['tenure', 'MonthlyCharges', 'TotalCharges']]
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2459, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2452     return self._numba_agg_general(
#    2453         grouped_mean,
#    2454         executor.float_dtype_mapping,
#    2455         engine_kwargs,
#    2456         min_periods=0,
#    2457     )
#    2458 else:
# -> 2459     result = self._cython_agg_general(
#    2460         "mean",
#    2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1488, in BlockManager.grouped_reduce(self, func)
#    1484 if blk.is_object:
#    1485     # split on object-dtype blocks bc some columns may raise
#    1486     #  while others do not.
#    1487     for sb in blk._split():
# -> 1488         applied = sb.apply(func)
#    1489         result_blocks = extend_blocks(applied, result_blocks)
#    1490 else:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2002, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1999     return result
#    2001 assert alt is not None
# -> 2002 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003 return result
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1948, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1946     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1947     # preserve the kind of exception that raised
# -> 1948     raise type(err)(msg) from err
#    1950 dtype = ser.dtype
#    1951 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# ### <span style="color:#3498DB">Point: 請進一步分析你想看到的數據
# * 如：不同性別&contract，人數是否有所差異？

# %%
dataset.pivot_table(index=['gender', 'Contract'], values='customerID', 
                    margins=True, aggfunc=['count'], margins_name= 'Total count')
# Out:
#                                 count
#                            customerID
# gender      Contract
# Female      Month-to-month       1925
#             One year              718
#             Two year              845
# Male        Month-to-month       1950
#             One year              755
#             Two year              850
# Total count                      7043

# %% [markdown]
# # 2. Data preprocessing

# %% [markdown]
# ## 2-1 處理NA

# %%
dataset.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#Removing missing values 
dataset.dropna(inplace = True)

# %% [markdown]
# ## 2-2 清整數據並轉dummy variable

# %%
#Remove customer IDs from the data set
df = dataset.iloc[:,1:]

#Convertin the predictor variable in a binary numeric variable
df['Churn'].replace(to_replace='Yes', value=1, inplace=True)
df['Churn'].replace(to_replace='No',  value=0, inplace=True)

#Let's convert all the categorical variables into dummy variables
df_dummies = pd.get_dummies(df)
df_dummies.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  gender_Male  \
# 0       1           29.85         29.85      0           True        False
# 1      34           56.95       1889.50      0          False         True
# 2       2           53.85        108.15      1          False         True
# 3      45           42.30       1840.75      0          False         True
# 4       2           70.70        151.65      1           True        False
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0             True            False       False         True           True
# 1             True            False        True        False           True
# 2             True            False        True        False           True
# 3             True            False        True        False           True
# 4             True            False        True        False           True
#
#    Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0           False             True             False             False
# 1           False            False              True              True
# 2           False            False              True              True
# 3           False             True             False             False
# 4           False            False              True              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  InternetService_DSL  \
# 0                            True              False                 True
# 1                           False              False                 True
# 2                           False              False                 True
# 3                            True              False                 True
# 4                           False              False                False
#
#    InternetService_Fiber optic  InternetService_No  OnlineSecurity_No  \
# 0                        False               False               True
# 1                        False               False              False
# 2                        False               False              False
# 3                        False               False              False
# 4                         True               False               True
#
#    OnlineSecurity_No internet service  OnlineSecurity_Yes  OnlineBackup_No  \
# 0                               False               False            False
# 1                               False                True             True
# 2                               False                True            False
# 3                               False                True             True
# 4                               False               False             True
#
#    OnlineBackup_No internet service  OnlineBackup_Yes  DeviceProtection_No  \
# 0                             False              True                 True
# 1                             False             False                False
# 2                             False              True                 True
# 3                             False             False                False
# 4                             False             False                 True
#
#    DeviceProtection_No internet service  DeviceProtection_Yes  TechSupport_No  \
# 0                                 False                 False            True
# 1                                 False                  True            True
# 2                                 False                 False            True
# 3                                 False                  True           False
# 4                                 False                 False            True
#
#    TechSupport_No internet service  TechSupport_Yes  StreamingTV_No  \
# 0                            False            False            True
# 1                            False            False            True
# 2                            False            False            True
# 3                            False             True            True
# 4                            False            False            True
#
#    StreamingTV_No internet service  StreamingTV_Yes  StreamingMovies_No  \
# 0                            False            False                True
# 1                            False            False                True
# 2                            False            False                True
# 3                            False            False                True
# 4                            False            False                True
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
# 1                                False                False
# 2                                False                False
# 3                                False                False
# 4                                False                False
#
#    Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 0                     True              False              False
# 1                    False               True              False
# 2                     True              False              False
# 3                    False               True              False
# 4                     True              False              False
#
#    PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                False                  True
# 1                 True                 False
# 2                False                  True
# 3                 True                 False
# 4                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False

# %% [markdown]
# # 3. Descriptive statistics

# %% [markdown]
# ## A. Demographics

# %%
colors = ['#4D3425','#E4512B']
ax = (df['gender'].value_counts()*100.0 /len(df)).plot(kind='bar',stacked = True, rot = 0,color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('% Customers')
ax.set_xlabel('Gender')
ax.set_ylabel('% Customers')
ax.set_title('Gender Distribution')

# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_x()+.15, i.get_height()-3.5, \
            str(round((i.get_height()/total), 1))+'%',
            fontsize=12,
            color='white',
           weight = 'bold')
plt.show()

# %%
ax = (df['SeniorCitizen'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12 )                                                                           
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('Senior Citizens',fontsize = 12)
ax.set_title('% of Senior Citizens', fontsize = 12)
plt.show()
# Out:
# Text(0.5, 1.0, '% of Senior Citizens')

# %%
df2 = pd.melt(dataset, id_vars=['customerID'], value_vars=['Dependents','Partner'])
df3 = df2.groupby(['variable','value']).count().unstack()
df3 = df3*100/len(dataset)
colors = ['#D4AC0D','#F8C471']
ax = df3.loc[:,'customerID'].plot.bar(stacked=True, color=colors,
                                      figsize=(8,6),rot = 0,
                                     width = 0.2)

ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('% Customers',size = 14)
ax.set_xlabel('')
ax.set_title('% Customers with dependents and partners',size = 14)
ax.legend(loc = 'center',prop={'size':14})

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
                weight = 'bold',
                size = 14)
    
# Dependents: 客戶是否有家屬 (Yes, No)  
# Partner: 客戶是否有合作夥伴 (Yes, No)               
plt.show()

# %%
colors = ['#2E86C1','#85C1E9']
partner_dependents = dataset.groupby(['Partner','Dependents']).size().unstack()

ax = (partner_dependents.T*100.0 / partner_dependents.T.sum()).T.plot(kind='bar',
                                                                width = 0.2,
                                                                stacked = True,
                                                                rot = 0, 
                                                                figsize = (8,6),
                                                                color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(loc='center',prop={'size':14},title = 'Dependents',fontsize =14)
ax.set_ylabel('% Customers',size = 14)
ax.set_title('% Customers with/without dependents based on whether they have a partner',size = 14)
ax.xaxis.label.set_size(14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
               weight = 'bold',
               size = 14)
plt.show()

# %% [markdown]
# 在有合作夥伴的客戶中，只有大約一半也有受撫養人，而另一半為單身。
# 此外，在沒有合作夥伴的客戶中，大多數 (90%) 為單身。

# %% [markdown]
# ## B. Customer Account Information:

# %% [markdown]
# ### <span style="color:#3498DB">Question: 請說明客戶停留月數的情況 </span>

# %%
ax = sns.distplot(df['tenure'], 
                  hist=True, 
                  kde=False, 
                  bins=int(180/5), 
                  color = '#3498DB', 
                  hist_kws={'edgecolor':'black'},
                  kde_kws={'linewidth': 4})
ax.set_ylabel('Customers count')
ax.set_xlabel('Tenure (months)')
ax.set_title('Customers tenure')
plt.show()
# Out:
# Text(0.5, 1.0, 'Customers tenure')

# %%
ax = df['Contract'].value_counts().plot(kind = 'bar',rot = 0, width = 0.3)
ax.set_ylabel('Customers count')
ax.set_title('Contract Type')
plt.show()
# Out:
# Text(0.5, 1.0, 'Contract Type')

# %%
fig, (ax1,ax2,ax3) = plt.subplots(nrows=1, ncols=3, sharey = True, figsize = (20,6))

ax = sns.distplot(df[df['Contract']=='Month-to-month']['tenure'],
                   hist=True, kde=False,
                   bins=int(180/5), color = 'turquoise',
                   hist_kws={'edgecolor':'black'},
                   kde_kws={'linewidth': 4},
                 ax=ax1)
ax.set_ylabel('Customers count')
ax.set_xlabel('Tenure (months)')
ax.set_title('Month to Month Contract')

ax = sns.distplot(df[df['Contract']=='One year']['tenure'],
                   hist=True, kde=False,
                   bins=int(180/5), color = 'steelblue',
                   hist_kws={'edgecolor':'black'},
                   kde_kws={'linewidth': 4},
                 ax=ax2)
ax.set_xlabel('Tenure (months)',size = 14)
ax.set_title('One Year Contract',size = 14)

ax = sns.distplot(df[df['Contract']=='Two year']['tenure'],
                   hist=True, kde=False,
                   bins=int(180/5), color = 'darkblue',
                   hist_kws={'edgecolor':'black'},
                   kde_kws={'linewidth': 4},
                 ax=ax3)

ax.set_xlabel('Tenure (months)')
ax.set_title('Two Year Contract')
plt.show()
# Out:
# Text(0.5, 1.0, 'Two Year Contract')

# %% [markdown]
# ### <span style="color:#3498DB">Question: 請問上述三種合約期間有何特性？ 你會建議公司對合約期間有何種設定</span>

# %% [markdown]
# ## C. Look at the distribution of various services used by customers

# %%
services = ['PhoneService','MultipleLines','InternetService','OnlineSecurity',
           'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']

fig, axes = plt.subplots(nrows = 3,ncols = 3,figsize = (15,12))
for i, item in enumerate(services):
    if i < 3:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i,0],rot = 0)
        
    elif i >=3 and i < 6:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-3,1],rot = 0)
        
    elif i < 9:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-6,2],rot = 0)
    ax.set_title(item)
plt.show()

# %% [markdown]
# ### <span style="color:#3498DB">Question: 請問瀏覽上述客戶所接受的各種服務，你有什麼想法</span>

# %% [markdown]
# ## D. Look at 'Churn' and understand its interaction with other important variables

# %%
P = dataset.groupby('Churn')['customerID'].count().reset_index()
P['Percentage'] = 100 * P['customerID']  / P['customerID'].sum()
P
# Out:
#   Churn  customerID  Percentage
# 0    No        5163   73.421502
# 1   Yes        1869   26.578498

# %% [markdown]
# ### D-1 Churn vs Tenure:

# %% [markdown]
# ### <span style="color:#3498DB">Question: 請問在多久的tenure客戶，churn的可能性較高？</span>

# %%
sns.boxplot(x = df.Churn, y = df.tenure)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# ### D-2 Churn by Contract Type

# %%
colors = ['#4D3425','#E4512B']
contract_churn = df.groupby(['Contract','Churn']).size().unstack()
ax = (contract_churn.T*100.0 / contract_churn.T.sum()).T.plot(kind='bar', width = 0.3, stacked = True,
                                      rot = 0, figsize = (10,6), color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(loc='best',prop={'size':14},title = 'Churn')
ax.set_ylabel('Customers count',size = 14)
ax.set_title('Churn by Contract Type',size = 14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
                weight = 'bold',
                size = 14)
plt.show()

# %% [markdown]
# ### D-3 Churn by Seniority

# %%
colors = ['#229954','#82E0AA']
seniority_churn = df.groupby(['SeniorCitizen','Churn']).size().unstack()

ax = (seniority_churn.T*100.0 / seniority_churn.T.sum()).T.plot(kind='bar',
                                                                width = 0.2,
                                                                stacked = True,
                                                                rot = 0, 
                                                                figsize = (8,6),
                                                                color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(loc='center',prop={'size':14},title = 'Churn')
ax.set_ylabel('% Customers')
ax.set_title('Churn by Seniority Level',size = 14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
               weight = 'bold',size =14)
plt.show()

# %% [markdown]
# ### D-4 Churn by Monthly Charges

# %%
ax = sns.kdeplot(dataset.MonthlyCharges[(dataset["Churn"] == 'No') ],
                color="Red", shade = True)
ax = sns.kdeplot(dataset.MonthlyCharges[(dataset["Churn"] == 'Yes') ],
                ax =ax, color="Blue", shade= True)
ax.legend(["Not Churn","Churn"],loc='upper right')
ax.set_ylabel('Density')
ax.set_xlabel('Monthly Charges')
ax.set_title('Distribution of monthly charges by churn')
plt.show()
# Out:
# Text(0.5, 1.0, 'Distribution of monthly charges by churn')

# %% [markdown]
# ### D-5 Churn by Total Charges

# %%
ax = sns.kdeplot(dataset.TotalCharges[(dataset["Churn"] == 'No') ],
                color="Red", shade = True)
ax = sns.kdeplot(dataset.TotalCharges[(dataset["Churn"] == 'Yes') ],
                ax =ax, color="Blue", shade= True)
ax.legend(["Not Churn","Churn"],loc='upper right')
ax.set_ylabel('Density')
ax.set_xlabel('Total Charges')
ax.set_title('Distribution of total charges by churn')
plt.show()
# Out:
# Text(0.5, 1.0, 'Distribution of total charges by churn')

# %% [markdown]
# # 3. Modeling

# %%
df_dummies.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  gender_Male  \
# 0       1           29.85         29.85      0           True        False
# 1      34           56.95       1889.50      0          False         True
# 2       2           53.85        108.15      1          False         True
# 3      45           42.30       1840.75      0          False         True
# 4       2           70.70        151.65      1           True        False
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0             True            False       False         True           True
# 1             True            False        True        False           True
# 2             True            False        True        False           True
# 3             True            False        True        False           True
# 4             True            False        True        False           True
#
#    Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0           False             True             False             False
# 1           False            False              True              True
# 2           False            False              True              True
# 3           False             True             False             False
# 4           False            False              True              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  InternetService_DSL  \
# 0                            True              False                 True
# 1                           False              False                 True
# 2                           False              False                 True
# 3                            True              False                 True
# 4                           False              False                False
#
#    InternetService_Fiber optic  InternetService_No  OnlineSecurity_No  \
# 0                        False               False               True
# 1                        False               False              False
# 2                        False               False              False
# 3                        False               False              False
# 4                         True               False               True
#
#    OnlineSecurity_No internet service  OnlineSecurity_Yes  OnlineBackup_No  \
# 0                               False               False            False
# 1                               False                True             True
# 2                               False                True            False
# 3                               False                True             True
# 4                               False               False             True
#
#    OnlineBackup_No internet service  OnlineBackup_Yes  DeviceProtection_No  \
# 0                             False              True                 True
# 1                             False             False                False
# 2                             False              True                 True
# 3                             False             False                False
# 4                             False             False                 True
#
#    DeviceProtection_No internet service  DeviceProtection_Yes  TechSupport_No  \
# 0                                 False                 False            True
# 1                                 False                  True            True
# 2                                 False                 False            True
# 3                                 False                  True           False
# 4                                 False                 False            True
#
#    TechSupport_No internet service  TechSupport_Yes  StreamingTV_No  \
# 0                            False            False            True
# 1                            False            False            True
# 2                            False            False            True
# 3                            False             True            True
# 4                            False            False            True
#
#    StreamingTV_No internet service  StreamingTV_Yes  StreamingMovies_No  \
# 0                            False            False                True
# 1                            False            False                True
# 2                            False            False                True
# 3                            False            False                True
# 4                            False            False                True
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
# 1                                False                False
# 2                                False                False
# 3                                False                False
# 4                                False                False
#
#    Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 0                     True              False              False
# 1                    False               True              False
# 2                     True              False              False
# 3                    False               True              False
# 4                     True              False              False
#
#    PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                False                  True
# 1                 True                 False
# 2                False                  True
# 3                 True                 False
# 4                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False

# %%
# We will use the data frame where we had created dummy variables
X = df_dummies.drop(columns = ['Churn'])
y = df_dummies['Churn'].values

# Scaling all the variables to a range of 0 to 1
from sklearn.preprocessing import MinMaxScaler
features = X.columns.values
scaler = MinMaxScaler(feature_range = (0,1))
scaler.fit(X)
X = pd.DataFrame(scaler.transform(X))
X.columns = features

# %%
# Create Train & Test Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# data 數量夠多，再把 training data 設定成 70 %
# random state 隨機總值

# %% [markdown]
# ## 3-1 Logistic Regression (PPT 2.1)

# %%
# Running logistic regression model
from sklearn.linear_model import LogisticRegression
model_log = LogisticRegression()
result = model_log.fit(X_train, y_train)

# %%
from sklearn import metrics
y_test_pred_log = model_log.predict(X_test)

print (metrics.accuracy_score(y_test, y_test_pred_log))
# Out:
# 0.8137882018479033

# %%
model_log.predict_proba(X_test)
# Out:
# array([[0.36691012, 0.63308988],
#        [0.83568389, 0.16431611],
#        [0.72336517, 0.27663483],
#        ...,
#        [0.94130745, 0.05869255],
#        [0.95234239, 0.04765761],
#        [0.98380158, 0.01619842]], shape=(1407, 2))

# %%
y_test_pred_log

# 貼標預設值為0.5
# Out:
# array([1, 0, 0, ..., 0, 0, 0], shape=(1407,))

# %%
# Create the Confusion matrix
cm = confusion_matrix(y_test, y_test_pred_log) 
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (28,20))

fig, ax = plt.subplots()
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')

class_names=[0,1]
tick_marks = np.arange(len(class_names))
plt.tight_layout()
plt.title('Confusion matrix\n', y=1.1)
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
ax.xaxis.set_label_position("top")
plt.ylabel('Actual label\n')
plt.xlabel('Predicted label\n')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label\n')

# %%
TP=196; FP=102; FN=159; TN=950

print(f'Accuracy : {round((196+950)/(196+102+950+159),3)}')    # (TP + TN) / (TP + FP + TN + FN) 
print(f'Precision : {round((196)/(196+102), 3)}')              # TP / (TP + FP)
print(f'Recall/Sensitivity : {round((196)/(196+159), 3)}')     # TP / (TP + FN)
print(f'Specificity : {round((950)/(950+102), 3)}')            # TN / (TN + FP)

# recall: 離開的這群人裡面有多少被預測到了
# Out:
# Accuracy : 0.814
# Precision : 0.658
# Recall/Sensitivity : 0.552
# Specificity : 0.903

# %%
from sklearn.metrics import RocCurveDisplay
ax = plt.gca()
log_disp = RocCurveDisplay.from_estimator(model_log, X_test, y_test, ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# ### <span style="color:#3498DB">Question: 什麼樣的因素與churn呈現明顯的正向影響與負向影響 </span>

# %%
# To get the weights of all the variables
weights = pd.Series(model_log.coef_[0], index=X.columns.values)
print (weights.sort_values(ascending = False)[:15].plot(kind='bar'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# * TotalCharges越高的，流失機會越大
# * 擁有1個月的合約期會增加流失流失的機會

# %%
print(weights.sort_values(ascending = False)[-10:-1].plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# * 兩年的合約會減少流失率
# * 擁有 InternetService DSL的客戶，流失率也會降低

# %% [markdown]
# ## 3-2 Support Vecor Machine (SVM) (PPT 2.2)

# %%
from sklearn.svm import SVC

model_svm = SVC(kernel='rbf') 
model_svm.fit(X_train,y_train)
y_test_pred_svm = model_svm.predict(X_test)
metrics.accuracy_score(y_test, y_test_pred_svm)
# Out:
# 0.8088130774697939

# %%
# Create the Confusion matrix
cm = confusion_matrix(y_test, y_test_pred_svm) 
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (28,20))

fig, ax = plt.subplots()
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')

class_names=[0,1]
tick_marks = np.arange(len(class_names))
plt.tight_layout()
plt.title('Confusion matrix\n', y=1.1)
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
ax.xaxis.set_label_position("top")
plt.ylabel('Actual label\n')
plt.xlabel('Predicted label\n')
# Out:
# Text(0.5, 8.5, 'Predicted label\n')

# %%
# TP=180, FP=94, FN=175, TN=958

print(f'Accuracy : {round((180+958)/(180+94+958+175),3)}')    # (TP + TN) / (TP + FP + TN + FN) 
print(f'Precision : {round((180)/(180+94), 3)}')              # TP / (TP + FP)
print(f'Recall/Sensitivity : {round((180)/(180+175), 3)}')     # TP / (TP + FN)
print(f'Specificity : {round((958)/(958+94), 3)}')            # TN / (TN + FP)
# Out:
# Accuracy : 0.809
# Precision : 0.657
# Recall/Sensitivity : 0.507
# Specificity : 0.911

# %%
ax = plt.gca()
log_disp = RocCurveDisplay.from_estimator(model_log, X_test, y_test, ax=ax, alpha=0.8)
svm_disp = RocCurveDisplay.from_estimator(model_svm, X_test, y_test, ax=ax, alpha=0.8)
plt.show()

# %%
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif

preprocessor = make_pipeline(SelectKBest(f_classif, k=10))  # 僅保留好的K個變數
SVM = make_pipeline(preprocessor, StandardScaler(), SVC(random_state=0))

# %%
SVM.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'pipeline', 'standardscaler', 'svc', 'pipeline__memory', 'pipeline__steps', 'pipeline__verbose', 'pipeline__selectkbest', 'pipeline__selectkbest__k', 'pipeline__selectkbest__score_func', 'standardscaler__copy', 'standardscaler__with_mean', 'standardscaler__with_std', 'svc__C', 'svc__break_ties', 'svc__cache_size', 'svc__class_weight', 'svc__coef0', 'svc__decision_function_shape', 'svc__degree', 'svc__gamma', 'svc__kernel', 'svc__max_iter', 'svc__probability', 'svc__random_state', 'svc__shrinking', 'svc__tol', 'svc__verbose'])

# %%
hyper_params_svm = {'svc__gamma':[0.001, 0.0001, 0.0005], 'svc__C':[1, 10, 100, 1000, 3000],}

# %%
grid_svm = GridSearchCV(SVM, hyper_params_svm,scoring='recall', cv=3) # GridSearchCV:網格搜索, cv:交叉驗證
grid_svm.fit(X_train, y_train)

print(grid_svm.best_params_)
# Out:
# {'svc__C': 10, 'svc__gamma': 0.0005}

# %%
y_test_pred_gridsvm = grid_svm.predict(X_test)
metrics.accuracy_score(y_test, y_test_pred_gridsvm)
# Out:
# 0.8088130774697939

# %%
ax = plt.gca()
log_disp = RocCurveDisplay.from_estimator(model_log, X_test, y_test, ax=ax, alpha=0.8)
grid_svm_disp = RocCurveDisplay.from_estimator(grid_svm, X_test, y_test, ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# ## 3-3  Decision Tree (PPT 2.3)

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt = DecisionTreeClassifier(criterion = 'gini')  # CART, 默認為gini
clf = model_dt.fit(X_train, y_train)

# Make predictions
y_test_pred_dt = model_dt.predict(X_test)
print(metrics.accuracy_score(y_test, y_test_pred_dt))
# Out:
# 0.7270788912579957

# %%
# Create the Confusion matrix
cm = confusion_matrix(y_test, y_test_pred_dt) 
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (28,20))

fig, ax = plt.subplots()
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')

class_names=[0,1]
tick_marks = np.arange(len(class_names))
plt.tight_layout()
plt.title('Confusion matrix\n', y=1.1)
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
ax.xaxis.set_label_position("top")
plt.ylabel('Actual label\n')
plt.xlabel('Predicted label\n')
# Out:
# Text(0.5, 8.5, 'Predicted label\n')

# %% [markdown]
# ### Decision Tree Optimization - Pruning

# %%
preprocessor = make_pipeline(SelectKBest(f_classif, k=8)) # 挑選出K個分數最高的特徵
DecisionTree = make_pipeline(preprocessor,DecisionTreeClassifier(random_state=0))

# %%
DecisionTree.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'pipeline', 'decisiontreeclassifier', 'pipeline__memory', 'pipeline__steps', 'pipeline__verbose', 'pipeline__selectkbest', 'pipeline__selectkbest__k', 'pipeline__selectkbest__score_func', 'decisiontreeclassifier__ccp_alpha', 'decisiontreeclassifier__class_weight', 'decisiontreeclassifier__criterion', 'decisiontreeclassifier__max_depth', 'decisiontreeclassifier__max_features', 'decisiontreeclassifier__max_leaf_nodes', 'decisiontreeclassifier__min_impurity_decrease', 'decisiontreeclassifier__min_samples_leaf', 'decisiontreeclassifier__min_samples_split', 'decisiontreeclassifier__min_weight_fraction_leaf', 'decisiontreeclassifier__random_state', 'decisiontreeclassifier__splitter'])

# %%
hyper_params_dt = {
    'decisiontreeclassifier__max_leaf_nodes':[10,20,30],    # 最多有多少個leaf nodes
    'decisiontreeclassifier__min_samples_leaf': [5,10,15],  # 要成為leaf nodes，最少需要多少資料
    'decisiontreeclassifier__max_depth': [5,10,15]          # 限制樹的高度最多幾層
}

# %%
grid_dt = GridSearchCV(DecisionTree, hyper_params_dt, scoring='recall', cv=3)
grid_dt.fit(X_train, y_train)
print(grid_dt.best_params_)
# Out:
# {'decisiontreeclassifier__max_depth': 10, 'decisiontreeclassifier__max_leaf_nodes': 20, 'decisiontreeclassifier__min_samples_leaf': 15}

# %%
y_test_pred_griddt = grid_dt.predict(X_test)
metrics.accuracy_score(y_test, y_test_pred_griddt)
# Out:
# 0.7953091684434968

# %%
from sklearn.metrics import RocCurveDisplay
ax = plt.gca()
log_disp = RocCurveDisplay.from_estimator(model_log, X_test, y_test, ax=ax, alpha=0.8)
grid_dt_disp = RocCurveDisplay.from_estimator(grid_dt, X_test, y_test, ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# ### Visualization

# %%
from sklearn import tree
print(tree.export_text(model_dt))
# Out:
# |--- feature_37 <= 0.50
# |   |--- feature_19 <= 0.50
# |   |   |--- feature_1 <= 0.83
# |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |--- feature_1 <= 0.49
# |   |   |   |   |   |   |--- feature_0 <= 0.82
# |   |   |   |   |   |   |   |--- feature_0 <= 0.73
# |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_42 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_42 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.73
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.74
# |   |   |   |   |   |   |   |   |   |--- feature_42 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_42 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.74
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.82
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.49
# |   |   |   |   |   |   |--- feature_1 <= 0.49
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.49
# |   |   |   |   |   |   |   |--- feature_2 <= 0.37
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.35
# |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_45 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_45 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.35
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.37
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.54
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.54
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.72
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.15
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.14
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.15
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |--- feature_1 <= 0.33
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.33
# |   |   |   |   |   |   |   |--- feature_0 <= 0.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  0.35
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.77
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.61
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.61
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.77
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |--- feature_1 <= 0.77
# |   |   |   |   |   |   |--- feature_14 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_14 >  0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 0.30
# |   |   |   |   |   |   |   |   |--- feature_39 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_39 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  0.30
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.77
# |   |   |   |   |   |   |--- feature_0 <= 0.58
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  0.58
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_1 >  0.83
# |   |   |   |--- feature_2 <= 0.75
# |   |   |   |   |--- feature_27 <= 0.50
# |   |   |   |   |   |--- feature_39 <= 0.50
# |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 0.61
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.61
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.60
# |   |   |   |   |   |   |   |   |--- feature_43 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_43 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.60
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_39 >  0.50
# |   |   |   |   |   |   |--- feature_0 <= 0.72
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  0.72
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_27 >  0.50
# |   |   |   |   |   |--- feature_0 <= 0.74
# |   |   |   |   |   |   |--- feature_0 <= 0.46
# |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.46
# |   |   |   |   |   |   |   |--- feature_1 <= 0.91
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.91
# |   |   |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.92
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  0.74
# |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |--- feature_38 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_38 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.67
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.67
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  0.75
# |   |   |   |   |--- feature_2 <= 1.00
# |   |   |   |   |   |--- feature_0 <= 0.98
# |   |   |   |   |   |   |--- feature_0 <= 0.96
# |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_24 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.90
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_24 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.90
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.96
# |   |   |   |   |   |   |   |--- feature_38 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_22 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_42 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_42 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_22 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_38 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  0.98
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  1.00
# |   |   |   |   |   |--- class: 1
# |   |--- feature_19 >  0.50
# |   |   |--- feature_38 <= 0.50
# |   |   |   |--- feature_1 <= 0.87
# |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |--- feature_1 <= 0.75
# |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 0.62
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.62
# |   |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.28
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.28
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.28
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.28
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.75
# |   |   |   |   |   |   |--- feature_1 <= 0.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.75
# |   |   |   |   |   |   |   |--- feature_1 <= 0.80
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.79
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.58
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.79
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  0.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |--- feature_1 <= 0.38
# |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.38
# |   |   |   |   |   |   |--- feature_36 <= 0.50
# |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_36 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.87
# |   |   |   |   |--- feature_1 <= 0.88
# |   |   |   |   |   |--- feature_0 <= 0.99
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  0.99
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  0.88
# |   |   |   |   |   |--- feature_1 <= 0.90
# |   |   |   |   |   |   |--- feature_1 <= 0.90
# |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.90
# |   |   |   |   |   |   |   |--- feature_2 <= 0.89
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.89
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.90
# |   |   |   |   |   |   |--- feature_42 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_42 >  0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 0.91
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.91
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.92
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.92
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_38 >  0.50
# |   |   |   |--- feature_1 <= 0.80
# |   |   |   |   |--- feature_1 <= 0.06
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  0.06
# |   |   |   |   |   |--- feature_36 <= 0.50
# |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.30
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.29
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.29
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.30
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.61
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.08
# |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.08
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.64
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.61
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.69
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_36 >  0.50
# |   |   |   |   |   |   |--- feature_2 <= 0.37
# |   |   |   |   |   |   |   |--- feature_2 <= 0.36
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.76
# |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.76
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_45 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_45 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.36
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  0.37
# |   |   |   |   |   |   |   |--- feature_2 <= 0.56
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.45
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.56
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.56
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.56
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.69
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.69
# |   |   |   |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |--- feature_1 >  0.80
# |   |   |   |   |--- feature_2 <= 0.76
# |   |   |   |   |   |--- feature_0 <= 0.85
# |   |   |   |   |   |   |--- feature_1 <= 0.93
# |   |   |   |   |   |   |   |--- feature_2 <= 0.23
# |   |   |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.23
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.81
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.81
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- feature_1 >  0.93
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  0.85
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  0.76
# |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |--- feature_13 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.85
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_13 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |--- feature_1 <= 0.89
# |   |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.85
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.89
# |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |--- feature_37 >  0.50
# |   |--- feature_17 <= 0.50
# |   |   |--- feature_0 <= 0.04
# |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |--- feature_0 <= 0.01
# |   |   |   |   |   |--- feature_41 <= 0.50
# |   |   |   |   |   |   |--- feature_43 <= 0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_45 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_45 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- feature_43 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_41 >  0.50
# |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.31
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  0.01
# |   |   |   |   |   |--- feature_24 <= 0.50
# |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.02
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.02
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_43 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_43 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_24 >  0.50
# |   |   |   |   |   |   |--- feature_36 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_36 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |--- feature_40 <= 0.50
# |   |   |   |   |   |   |--- feature_1 <= 0.42
# |   |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_13 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_13 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_1 >  0.42
# |   |   |   |   |   |   |   |--- feature_1 <= 0.48
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.48
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_40 >  0.50
# |   |   |   |   |   |   |--- feature_1 <= 0.06
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.06
# |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |--- feature_27 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_27 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.36
# |   |   |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.36
# |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_24 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_24 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |--- feature_2 <= 0.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.00
# |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_0 >  0.04
# |   |   |   |--- feature_14 <= 0.50
# |   |   |   |   |--- feature_22 <= 0.50
# |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |--- feature_1 <= 0.01
# |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.01
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_41 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_41 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.01
# |   |   |   |   |   |   |   |--- feature_2 <= 0.04
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.04
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.04
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.04
# |   |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |--- feature_0 <= 0.12
# |   |   |   |   |   |   |   |--- feature_2 <= 0.07
# |   |   |   |   |   |   |   |   |--- feature_45 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_45 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_2 >  0.07
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  0.12
# |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.60
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.60
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_22 >  0.50
# |   |   |   |   |   |--- feature_2 <= 0.06
# |   |   |   |   |   |   |--- feature_1 <= 0.36
# |   |   |   |   |   |   |   |--- feature_45 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.05
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.05
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_45 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.27
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.27
# |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.36
# |   |   |   |   |   |   |   |--- feature_1 <= 0.51
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.51
# |   |   |   |   |   |   |   |   |--- feature_41 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_41 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  0.06
# |   |   |   |   |   |   |--- feature_0 <= 0.33
# |   |   |   |   |   |   |   |--- feature_1 <= 0.47
# |   |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# ...
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_22 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.30
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_43 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_43 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.17
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.17
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.85
# |   |   |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.85
# |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.13
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.30
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.30
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |--- feature_0 >  0.71
# |   |   |   |   |   |--- feature_2 <= 0.78
# |   |   |   |   |   |   |--- feature_2 <= 0.60
# |   |   |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.67
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.67
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.60
# |   |   |   |   |   |   |   |--- feature_2 <= 0.60
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.60
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  0.78
# |   |   |   |   |   |   |--- feature_1 <= 0.88
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.88
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_44 >  0.50
# |   |   |   |   |--- feature_2 <= 0.35
# |   |   |   |   |   |--- feature_2 <= 0.34
# |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.19
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.19
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.24
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.24
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.32
# |   |   |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.32
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.39
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.39
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 0.39
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.33
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.78
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.77
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.78
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.33
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_0 >  0.39
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.29
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.29
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  0.34
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  0.35
# |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |--- feature_2 <= 0.40
# |   |   |   |   |   |   |   |--- feature_2 <= 0.39
# |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.39
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  0.40
# |   |   |   |   |   |   |   |--- feature_2 <= 0.42
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  0.42
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.46
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.46
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.51
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.51
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |--- feature_1 <= 0.62
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.62
# |   |   |   |   |   |   |   |--- feature_0 <= 0.82
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.92
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.47
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.47
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  0.82
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1

# %%
# !pip3 install six
# !pip3 install pydotplus

# %%
# http://www.graphviz.org/download/
# InvocationException: GraphViz's executables not found

# %%
# from six import StringIO  
# from IPython.display import Image  
# from sklearn.tree import export_graphviz
# import pydotplus


# dot_data = StringIO()
# export_graphviz(model_dt, out_file=dot_data,  
#                 filled=True, rounded=True,
#                 special_characters=True)

# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# Image(graph.create_png())

# %% [markdown]
# ## 3-4 Random Forest (PPT 2.4)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)

# Make predictions
y_test_pred_rf = model_rf.predict(X_test)
print(metrics.accuracy_score(y_test, y_test_pred_rf))
# Out:
# 0.7903340440653873

# %%
# Create the Confusion matrix
cm = confusion_matrix(y_test, y_test_pred_rf) 
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (28,20))

fig, ax = plt.subplots()
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')

class_names=[0,1]
tick_marks = np.arange(len(class_names))
plt.tight_layout()
plt.title('Confusion matrix\n', y=1.1)
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
ax.xaxis.set_label_position("top")
plt.ylabel('Actual label\n')
plt.xlabel('Predicted label\n')
# Out:
# Text(0.5, 8.5, 'Predicted label\n')

# %% [markdown]
# ### <span style="color:#3498DB">Question: 請自行算出下列衡量標準，並與Logistic regression結果比較 </span>

# %% [markdown]
# * Accuracy
# * Precision
# * Recall/Sensitivity
# * Specificity

# %% [markdown]
# ### <span style="color:#3498DB">Question: 何種原因對churn的重要性最高？請與Logistic Regression相互比較 </span>

# %%
importances = model_rf.feature_importances_
weights = pd.Series(importances,
                 index=X.columns.values)
weights.sort_values()[-10:].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Random Forest Optimization
#
# * n_estimators: int，森林裡樹木的數量，預設為10
# * max_depth: int或None，樹的最大深度，預設為None
# * bootstrap: 是否隨機抽樣，默認為True
# * max_features: 每個決策樹最大的特徵數量，預設為”auto”，max_features = n_features
# * max_leaf_nodes: 通過限制最大葉子節點數，防止過擬合，默認是"None”。如加了限制，會建立在最大葉子節點數內最優的決策樹。如果特徵不多，可以不考慮這個值

# %%
preprocessor = make_pipeline(SelectKBest(f_classif, k=10))
RandomForest = make_pipeline(preprocessor, RandomForestClassifier(random_state=0))

# %%
RandomForest.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'pipeline', 'randomforestclassifier', 'pipeline__memory', 'pipeline__steps', 'pipeline__verbose', 'pipeline__selectkbest', 'pipeline__selectkbest__k', 'pipeline__selectkbest__score_func', 'randomforestclassifier__bootstrap', 'randomforestclassifier__ccp_alpha', 'randomforestclassifier__class_weight', 'randomforestclassifier__criterion', 'randomforestclassifier__max_depth', 'randomforestclassifier__max_features', 'randomforestclassifier__max_leaf_nodes', 'randomforestclassifier__max_samples', 'randomforestclassifier__min_impurity_decrease', 'randomforestclassifier__min_samples_leaf', 'randomforestclassifier__min_samples_split', 'randomforestclassifier__min_weight_fraction_leaf', 'randomforestclassifier__n_estimators', 'randomforestclassifier__n_jobs', 'randomforestclassifier__oob_score', 'randomforestclassifier__random_state', 'randomforestclassifier__verbose', 'randomforestclassifier__warm_start'])

# %%
hyper_params_rf = {"randomforestclassifier__n_estimators":[10,50,100,150,200],
                   "randomforestclassifier__max_depth":[5,10,15,20], 
                   "randomforestclassifier__max_leaf_nodes":[10,20,30]}

# %%
grid_rf = GridSearchCV(RandomForest, hyper_params_rf, scoring='recall', cv=3)
grid_rf.fit(X_train, y_train)
print(grid_rf.best_params_)
# Out:
# {'randomforestclassifier__max_depth': 15, 'randomforestclassifier__max_leaf_nodes': 30, 'randomforestclassifier__n_estimators': 150}

# %%
y_test_pred_gridrf = grid_rf.predict(X_test)
metrics.accuracy_score(y_test, y_test_pred_gridrf)
# Out:
# 0.8031272210376688

# %%
from sklearn.metrics import RocCurveDisplay
ax = plt.gca()
log_disp = RocCurveDisplay.from_estimator(model_log, X_test, y_test, ax=ax, alpha=0.8)
grid_rf_disp = RocCurveDisplay.from_estimator(grid_rf, X_test, y_test, ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# ## 3.5 XgBoost (PPT.5)

# %% [markdown]
# ### 3.5.1 Basic

# %%
from xgboost import XGBClassifier
model_xg = XGBClassifier()
model_xg.fit(X_train, y_train)
y_test_pred_xg = model_xg.predict(X_test)
metrics.accuracy_score(y_test, y_test_pred_xg)
# Out:
# 0.7846481876332623

# %%
# Create the Confusion matrix
cm = confusion_matrix(y_test, y_test_pred_xg) 
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (28,20))

fig, ax = plt.subplots()
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, fmt='g')

class_names=[0,1]
tick_marks = np.arange(len(class_names))
plt.tight_layout()
plt.title('Confusion matrix\n', y=1.1)
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
ax.xaxis.set_label_position("top")
plt.ylabel('Actual label\n')
plt.xlabel('Predicted label\n')
# Out:
# Text(0.5, 8.5, 'Predicted label\n')

# %%
# TP=178, FP=126, FN=177, TN=926

print(f'Accuracy : {round((178+926)/(178+126+926+177),3)}')    # (TP + TN) / (TP + FP + TN + FN) 
print(f'Precision : {round((178)/(178+126), 3)}')              # TP / (TP + FP)
print(f'Recall/Sensitivity : {round((178)/(178+177), 3)}')     # TP / (TP + FN)
print(f'Specificity : {round((958)/(958+126), 3)}')            # TN / (TN + FP)
# Out:
# Accuracy : 0.785
# Precision : 0.586
# Recall/Sensitivity : 0.501
# Specificity : 0.884

# %%
from sklearn.metrics import RocCurveDisplay
ax = plt.gca()
log_disp = RocCurveDisplay.from_estimator(model_log, X_test, y_test, ax=ax, alpha=0.8)
model_xg_disp = RocCurveDisplay.from_estimator(model_xg, X_test, y_test, ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# ### 3.5.2 XgBoost Optimization
#
# | 參數                      | 功能說明                      |
# | ----------------------- | ------------------------- |
# | `n_estimators`          | 樹的數量，太少會欠擬合，太多可能過擬合       |
# | `max_depth`             | 樹的最大深度，影響模型複雜度            |
# | `learning_rate` (`eta`) | 每棵樹學習貢獻度，太大會過擬合，太小則學習太慢   |
# | `subsample`             | 每次訓練用多少比例樣本（避免過擬合）        |
# | `colsample_bytree`      | 每棵樹訓練時隨機取多少比例的特徵          |
# | `gamma`                 | 最小 loss 減少才允許分裂的閾值（越大越保守） |
# | `min_child_weight`      | 控制葉節點最小樣本總權重（防止過擬合）       |

# %% [markdown]
# #### 3.5.2.1 GridSearchCV

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200],
    'subsample': [0.8, 1.0]
}

grid_search = GridSearchCV(XGBClassifier(), param_grid, scoring='recall', cv=3)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 取得最佳模型
best_model = grid_search.best_estimator_

# 測試集預測
y_pred = best_model.predict(X_test)

# 混淆矩陣
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# precision: 預測為流失的客戶中有多少是真正流失的？
# recall: 所有真正流失的客戶中，有多少被成功預測出來？
# f1-score: precision 和 recall 的加權平均（兼顧準確與完整）
#
# 這對流失預測特別重要，recall 通常要特別關注，避免漏掉會流失的客戶。
#
# * TN（左上）：預測為不流失，實際也不流失（947 人）
# * FP（右上）：預測會流失，但實際沒有（105 人，誤殺）
# * FN（左下）：預測不會流失，但實際流失了（169 人，漏報 ⚠）
# * TP（右下）：預測會流失，實際也流失（186 人）
#
# → 若 FN 很多，要調高 recall（召回率）！

# %%
TP=186; FP=105; FN=169; TN=947

print(f'Accuracy : {round((TP + TN) / (TP + FP + TN + FN),3)}') 
print(f'Precision : {round(TP / (TP + FP), 3)}')                  
print(f'Recall/Sensitivity : {round(TP / (TP + FN), 3)}')       
print(f'Specificity : {round(TN / (TN + FP), 3)}')

# %% [markdown]
# #### 3.5.2.2 RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

# 設定參數範圍
param_dist = {
    'n_estimators': randint(100, 500),
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.2),
    'subsample': uniform(0.7, 0.3),
    'colsample_bytree': uniform(0.7, 0.3),
    'gamma': uniform(0, 0.5),
    'min_child_weight': randint(1, 10)
}

# 執行隨機搜尋: 「用隨機搜尋的方式，從你定義好的參數空間中，試 30 組組合，並用交叉驗證比出誰最好，最後挑出表現最好的 XGBoost 模型。」
random_search = RandomizedSearchCV(
    estimator=XGBClassifier(eval_metric='logloss'), # 設定用來衡量模型好壞的內部評估方式，這裡是「對數損失」，常用於分類。
    param_distributions=param_dist,  # 想要隨機試哪些參數組合。
    n_iter=30,         # 總共要嘗試幾組參數組合。這裡是試 30 組，數量愈多愈可能找到最佳，但花的時間也會增加。
    scoring='recall', # 用recall來評估每一組模型的好壞
    cv=3,             # 使用 3 折交叉驗證（Cross-Validation）：把訓練資料分成 3 份，每次用其中兩份訓練、一份驗證，重複三次平均，提升評估準確性。
    verbose=1,       # 讓執行過程有顯示輸出資訊，方便觀察訓練進度。
    random_state=42, # 為了確保每次執行結果一致（可重現），設定隨機種子。
    n_jobs=-1        # 使用電腦上所有核心來加速運算（平行運算），節省訓練時間。
)

random_search.fit(X_train, y_train)

print("最佳參數組合：", random_search.best_params_)
print("交叉驗證最佳準確率：", random_search.best_score_)

# %%
best_model = random_search.best_estimator_

y_pred = best_model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("測試集準確率：", acc)

# %%
# 取得最佳模型
best_model2 = random_search.best_estimator_

# 測試集預測
y_pred = best_model2.predict(X_test)

# 混淆矩陣
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model2.classes_)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# * TN（左上）：預測為不流失，實際也不流失（937 人）
# * FP（右上）：預測會流失，但實際沒有（115 人，誤殺）
# * FN（左下）：預測不會流失，但實際流失了（163 人，漏報 ⚠）
# * TP（右下）：預測會流失，實際也流失（192 人）

# %%
TP=192; FP=115; FN=163; TN=937

print(f'Accuracy : {round((TP + TN) / (TP + FP + TN + FN),3)}') 
print(f'Precision : {round(TP / (TP + FP), 3)}')                  
print(f'Recall/Sensitivity : {round(TP / (TP + FN), 3)}')       
print(f'Specificity : {round(TN / (TN + FP), 3)}')

# %% [markdown]
# ----------

# %% [markdown]
# ### <span style="color:#3498DB">Question: 總上四種模型，請問你要選哪個？為何？ </span>
