# %% [markdown]
# Reference: https://www.kaggle.com/datasets/rohan0301/unsupervised-learning-on-country-data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import scipy.cluster.hierarchy as hcluster
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# # 1. import data
#
# ### <span style="color:#3498DB">Point: 了解資料形式</span>

# %%
dict_df = pd.read_csv('data-dictionary.csv')
df = pd.read_csv('Country-data.csv')

# %%
dict_df
# Out:
#   Column Name                                        Description
# 0     country                                Name of the country
# 1  child_mort  Death of children under 5 years of age per 100...
# 2     exports  Exports of goods and services per capita. Give...
# 3      health  Total health spending per capita. Given as %ag...
# 4     imports  Imports of goods and services per capita. Give...
# 5      Income                              Net income per person
# 6   Inflation  The measurement of the annual growth rate of t...
# 7  life_expec  The average number of years a new born child w...
# 8   total_fer  The number of children that would be born to e...
# 9        gdpp  The GDP per capita. Calculated as the Total GD...

# %% [markdown]
# * Child Mortality Rate : 每 1000 名活產中 5 歲以下兒童死亡人數
# * Fertility Rate: 在當前年齡-生育率保持不變的情況下，每位女性將生育的孩子數量
# * Life Expectancy: 如果當前的死亡率模式保持不變，新生兒的平均壽命
# * Health : Health總支出佔 GDP 總額的百分比
# * gdpp : 總 GDP 除以總人口
# * income：人均淨收入
# * Inflation(通膨): The measurement of the annual growth rate of the Total GDP
# * Exports: Exports of goods and services. 以佔總 GDP 的百分比表示
# * Imports: Imports of goods and services. 以佔總 GDP 的百分比表示

# %%
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# # 2. Descriptive statistics

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %% [markdown]
# ### <span style="color:#3498DB">Point1: 請觀察各變數之間的關係</span>
# ### <span style="color:#3498DB">Point2: 請判斷各變數之間是否有共線關係</span>

# %%
data=df.drop(['country'],axis=1)

# %%
#correlation 
corrmat=data.corr()
fig, ax = plt.subplots(figsize = (18, 10))
sns.heatmap(corrmat, annot = True, annot_kws={'size': 12})
# Out:
# <Axes: >

# %% [markdown]
# ### <span style="color:#3498DB">Point: 請觀察各變數的分佈情形與交互關係</span>

# %%
sns.pairplot(df)

# %% [markdown]
# ### <span style="color:#3498DB">Point: 請觀察每個國家在變數之間的情況</span>

# %%
def des_df(var):
    des_df = df[['country',var]].sort_values(var, ascending = False)
    return des_df

def des_plot(var, ylab):
    plt.figure(figsize = (30,5))    
    ax = sns.barplot(x='country', y=var, data= des_df(var))
    ax.set(xlabel = '', ylabel= ylab)
    plt.xticks(rotation=90)
    return plt.show()

# %% [markdown]
# ## Child Mortality Rate : 每 1000 名活產中 5 歲以下兒童死亡人數

# %%
des_df('child_mort')
# Out:
#                       country  child_mort
# 66                      Haiti       208.0
# 132              Sierra Leone       160.0
# 32                       Chad       150.0
# 31   Central African Republic       149.0
# 97                       Mali       137.0
# ..                        ...         ...
# 53                    Finland         3.0
# 144                    Sweden         3.0
# 91                 Luxembourg         2.8
# 133                 Singapore         2.8
# 68                    Iceland         2.6
#
# [167 rows x 2 columns]

# %%
des_plot('child_mort', 'Child Mortality Rate')

# %% [markdown]
# ## Fertility Rate: 在當前年齡-生育率保持不變的情況下，每位女性將生育的孩子數量

# %%
des_df('total_fer')
# Out:
#                     country  total_fer
# 112                   Niger       7.49
# 32                     Chad       6.59
# 97                     Mali       6.55
# 37         Congo, Dem. Rep.       6.54
# 26                  Burundi       6.26
# ..                      ...        ...
# 20   Bosnia and Herzegovina       1.31
# 102                 Moldova       1.27
# 67                  Hungary       1.25
# 138             South Korea       1.23
# 133               Singapore       1.15
#
# [167 rows x 2 columns]

# %%
des_plot('total_fer', 'Fertility Rate')

# %% [markdown]
# ## Life Expectancy: 如果當前的死亡率模式保持不變，新生兒的平均壽命

# %%
des_df('life_expec')
# Out:
#                       country  life_expec
# 77                      Japan        82.8
# 133                 Singapore        82.7
# 145               Switzerland        82.2
# 68                    Iceland        82.0
# 7                   Australia        82.0
# ..                        ...         ...
# 94                     Malawi        53.1
# 166                    Zambia        52.0
# 31   Central African Republic        47.5
# 87                    Lesotho        46.5
# 66                      Haiti        32.1
#
# [167 rows x 2 columns]

# %%
des_plot('life_expec', 'Life Expectancy')

# %% [markdown]
# ## Health : Health總支出佔 GDP 總額的百分比

# %%
des_df('health')
# Out:
#                    country  health
# 159          United States   17.90
# 101  Micronesia, Fed. Sts.   14.20
# 132           Sierra Leone   13.10
# 54                  France   11.90
# 110            Netherlands   11.90
# ..                     ...     ...
# 154           Turkmenistan    2.50
# 38             Congo, Rep.    2.46
# 116               Pakistan    2.20
# 107                Myanmar    1.97
# 123                  Qatar    1.81
#
# [167 rows x 2 columns]

# %%
des_plot('health', 'Health')

# %% [markdown]
# ## The GDP per capita : 總 GDP 除以總人口

# %%
des_df('gdpp')
# Out:
#               country    gdpp
# 91         Luxembourg  105000
# 114            Norway   87800
# 145       Switzerland   74600
# 123             Qatar   70300
# 44            Denmark   58000
# ..                ...     ...
# 132      Sierra Leone     399
# 112             Niger     348
# 37   Congo, Dem. Rep.     334
# 88            Liberia     327
# 26            Burundi     231
#
# [167 rows x 2 columns]

# %%
des_plot('gdpp', 'GDP per capita')

# %% [markdown]
# ## income：人均淨收入

# %%
des_df('income')
# Out:
#                       country  income
# 123                     Qatar  125000
# 91                 Luxembourg   91700
# 23                     Brunei   80600
# 82                     Kuwait   75200
# 133                 Singapore   72100
# ..                        ...     ...
# 31   Central African Republic     888
# 112                     Niger     814
# 26                    Burundi     764
# 88                    Liberia     700
# 37           Congo, Dem. Rep.     609
#
# [167 rows x 2 columns]

# %%
des_plot('income', 'Per capita Income')

# %% [markdown]
# ## Inflation(通膨): The measurement of the annual growth rate of the Total GDP

# %%
des_df('inflation')
# Out:
#                country  inflation
# 113            Nigeria    104.000
# 163          Venezuela     45.900
# 103           Mongolia     39.200
# 149        Timor-Leste     26.500
# 49   Equatorial Guinea     24.900
# ..                 ...        ...
# 135           Slovenia     -0.987
# 43      Czech Republic     -1.430
# 77               Japan     -1.900
# 73             Ireland     -3.220
# 131         Seychelles     -4.210
#
# [167 rows x 2 columns]

# %%
des_plot('inflation', 'Inflation')

# %% [markdown]
# ## Exports: Exports of goods and services. 以佔總 GDP 的百分比表示

# %%
des_df('exports')
# Out:
#          country  exports
# 133    Singapore  200.000
# 91    Luxembourg  175.000
# 98         Malta  153.000
# 73       Ireland  103.000
# 131   Seychelles   93.800
# ..           ...      ...
# 109        Nepal    9.580
# 26       Burundi    8.920
# 50       Eritrea    4.790
# 149  Timor-Leste    2.200
# 107      Myanmar    0.109
#
# [167 rows x 2 columns]

# %%
des_plot('exports', 'Exports')

# %% [markdown]
# ## Imports: Imports of goods and services. 以佔總 GDP 的百分比表示

# %%
des_df('imports')
# Out:
#            country   imports
# 133      Singapore  174.0000
# 98           Malta  154.0000
# 91      Luxembourg  142.0000
# 131     Seychelles  108.0000
# 87         Lesotho  101.0000
# ..             ...       ...
# 5        Argentina   16.0000
# 159  United States   15.8000
# 77           Japan   13.6000
# 22          Brazil   11.8000
# 107        Myanmar    0.0659
#
# [167 rows x 2 columns]

# %%
des_plot('imports', 'Imports')

# %% [markdown]
# # 3. Modeling

# %%
data = pd.DataFrame(df, columns = ['child_mort', 'exports', 'health', 'imports', 'income',
                                   'inflation', 'life_expec', 'total_fer', 'gdpp'])
data.head()
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2        27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3       119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4        10.3     45.5    6.03     58.9   19100       1.44        76.8
#
#    total_fer   gdpp
# 0       5.82    553
# 1       1.65   4090
# 2       2.89   4460
# 3       6.16   3530
# 4       2.13  12200

# %%
# Standarisation technique for scaling
scaler = StandardScaler()
scaled = scaler.fit_transform(data)
data_scaled=pd.DataFrame(scaled,columns=data.columns)

# %%
data_scaled.head()
# Out:
#    child_mort   exports    health   imports    income  inflation  life_expec  \
# 0    1.291532 -1.138280  0.279088 -0.082455 -0.808245   0.157336   -1.619092
# 1   -0.538949 -0.479658 -0.097016  0.070837 -0.375369  -0.312347    0.647866
# 2   -0.272833 -0.099122 -0.966073 -0.641762 -0.220844   0.789274    0.670423
# 3    2.007808  0.775381 -1.448071 -0.165315 -0.585043   1.387054   -1.179234
# 4   -0.695634  0.160668 -0.286894  0.497568  0.101732  -0.601749    0.704258
#
#    total_fer      gdpp
# 0   1.902882 -0.679180
# 1  -0.859973 -0.485623
# 2  -0.038404 -0.465376
# 3   2.128151 -0.516268
# 4  -0.541946 -0.041817

# %% [markdown]
# ## 3.1 HIERARCHICAL CLUSTERING

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %% [markdown]
# ### 3.1.1 HC Modeling

# %% [markdown]
# * metric: 距離的計算方式
# * method: 群與群之間的計算方式，”single”, “complete”, “average”, “weighted”, “centroid”, “median”, “ward”

# %%
# Single linkage
plt.figure(figsize = (20,10))
mergings = linkage(data_scaled, method='single', metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# Average linkage
plt.figure(figsize = (20,10))
mergings = linkage(data_scaled, method='average', metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# Centroid linkage
plt.figure(figsize = (20,10))
mergings = linkage(data_scaled, method='centroid', metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# Ward method
plt.figure(figsize = (20,10))
mergings = linkage(data_scaled, method='ward',metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# 3 clusters
h_cluster = cut_tree(mergings, n_clusters=3).reshape(-1, )

# %%
pred = pd.DataFrame(h_cluster, columns=['h_cluster'])
hierarchy_result = pd.concat([df.reset_index(drop=True), pred], axis=1)
hierarchy_result
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  h_cluster
# 0         9.44        56.2       5.82    553          0
# 1         4.49        76.3       1.65   4090          1
# 2        16.10        76.5       2.89   4460          1
# 3        22.40        60.1       6.16   3530          1
# 4         1.44        76.8       2.13  12200          1
# ..         ...         ...        ...    ...        ...
# 162       2.62        63.0       3.50   2970          1
# 163      45.90        75.4       2.47  13500          1
# 164      12.10        73.1       1.95   1310          1
# 165      23.60        67.5       4.67   1310          1
# 166      14.00        52.0       5.40   1460          0
#
# [167 rows x 11 columns]

# %%
# Number of countries in each cluster
pred.value_counts()
# Out:
# h_cluster
# 1            106
# 2             34
# 0             27
# Name: count, dtype: int64

# %% [markdown]
# ### 3.1.2 HC result analysis
# ### <span style="color:#3498DB">Question: 請分析各群結果</span>

# %%
hierarchy_result[hierarchy_result['h_cluster'] == 0].head()
# Out:
#          country  child_mort  exports  health  imports  income  inflation  \
# 0    Afghanistan        90.2    10.00    7.58     44.9    1610      9.440
# 17         Benin       111.0    23.80    4.10     37.2    1820      0.885
# 25  Burkina Faso       116.0    19.20    6.74     29.6    1430      6.810
# 26       Burundi        93.6     8.92   11.60     39.2     764     12.300
# 28      Cameroon       108.0    22.20    5.13     27.0    2660      1.910
#
#     life_expec  total_fer  gdpp  h_cluster
# 0         56.2       5.82   553          0
# 17        61.8       5.36   758          0
# 25        57.9       5.87   575          0
# 26        57.7       6.26   231          0
# 28        57.3       5.11  1310          0

# %%
hierarchy_result[hierarchy_result['h_cluster'] == 1].head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
#
#    inflation  life_expec  total_fer   gdpp  h_cluster
# 1       4.49        76.3       1.65   4090          1
# 2      16.10        76.5       2.89   4460          1
# 3      22.40        60.1       6.16   3530          1
# 4       1.44        76.8       2.13  12200          1
# 5      20.90        75.8       2.37  10300          1

# %%
hierarchy_result[hierarchy_result['h_cluster'] == 2].head()
# Out:
#       country  child_mort  exports  health  imports  income  inflation  \
# 7   Australia         4.8     19.8    8.73     20.9   41400      1.160
# 8     Austria         4.3     51.3   11.00     47.8   43200      0.873
# 11    Bahrain         8.6     69.5    4.97     50.9   41100      7.440
# 15    Belgium         4.5     76.4   10.70     74.7   41100      1.880
# 23     Brunei        10.5     67.4    2.84     28.0   80600     16.700
#
#     life_expec  total_fer   gdpp  h_cluster
# 7         82.0       1.93  51900          2
# 8         80.5       1.44  46900          2
# 11        76.0       2.16  20700          2
# 15        80.0       1.86  44400          2
# 23        77.1       1.84  35300          2

# %%
hierarchy_result.groupby(['h_cluster'], as_index=True).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
#     895     res = extract_result(res)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2461, in GroupBy.mean.<locals>.<lambda>(x)
#    2458 else:
#    2459     result = self._cython_agg_general(
#    2460         "mean",
# -> 2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'AfghanistanBeninBurkina FasoBurundiCameroonCentral African RepublicChadComorosCongo, Dem. Rep.Cote d'IvoireGambiaGuineaGuinea-BissauHaitiKenyaMadagascarMalawiMaliMozambiqueNigerRwandaSenegalSierra LeoneTanzaniaTogoUgandaZambia' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 hierarchy_result.groupby(['h_cluster'], as_index=True).mean()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2459, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2452     return self._numba_agg_general(
#    2453         grouped_mean,
#    2454         executor.float_dtype_mapping,
#    2455         engine_kwargs,
#    2456         min_periods=0,
#    2457     )
#    2458 else:
# -> 2459     result = self._cython_agg_general(
#    2460         "mean",
#    2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1488, in BlockManager.grouped_reduce(self, func)
#    1484 if blk.is_object:
#    1485     # split on object-dtype blocks bc some columns may raise
#    1486     #  while others do not.
#    1487     for sb in blk._split():
# -> 1488         applied = sb.apply(func)
#    1489         result_blocks = extend_blocks(applied, result_blocks)
#    1490 else:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:2002, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1999     return result
#    2001 assert alt is not None
# -> 2002 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003 return result
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1948, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1946     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1947     # preserve the kind of exception that raised
# -> 1948     raise type(err)(msg) from err
#    1950 dtype = ser.dtype
#    1951 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# * Child Mortality Rate : 每 1000 名活產中 5 歲以下兒童死亡人數
# * Fertility Rate: 在當前年齡-生育率保持不變的情況下，每位女性將生育的孩子數量
# * Life Expectancy: 如果當前的死亡率模式保持不變，新生兒的平均壽命
# * Health : Health總支出佔 GDP 總額的百分比
# * gdpp : 總 GDP 除以總人口
# * income：人均淨收入
# * Inflation(通膨): The measurement of the annual growth rate of the Total GDP
# * Exports: Exports of goods and services. 以佔總 GDP 的百分比表示
# * Imports: Imports of goods and services. 以佔總 GDP 的百分比表示

# %% [markdown]
# ### <span style="color:#3498DB">Question: gdpp相對較高的國家，各變數表現的狀況為何？</span>

# %%
# Scatter plot on Original attributes to visualize the spread of the data
plt.figure(figsize = (25,15))
plt.subplot(5,1,1)
sns.scatterplot(x = 'gdpp', y = 'total_fer', hue='h_cluster',
                data = hierarchy_result, legend='full', palette="Set1")
plt.subplot(5,1,2)
sns.scatterplot(x = 'gdpp', y = 'inflation', hue='h_cluster', 
                data = hierarchy_result, legend='full', palette="Set1")
plt.subplot(5,1,3)
sns.scatterplot(x = 'gdpp', y = 'health', hue='h_cluster', 
                data = hierarchy_result, legend='full', palette="Set1")
plt.subplot(5,1,4)
sns.scatterplot(x = 'gdpp', y = 'imports', hue='h_cluster', 
                data = hierarchy_result, legend='full', palette="Set1")
plt.subplot(5,1,5)
sns.scatterplot(x = 'gdpp', y = 'exports', hue='h_cluster', 
                data = hierarchy_result, legend='full', palette="Set1")

plt.show()

# %% [markdown]
# ### <span style="color:#3498DB">Question: 請觀察極端值</span>

# %%
hierarchy_result.sort_values(by=['inflation'], ascending=False).head(5)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 113            Nigeria       130.0     25.3    5.07     17.4    5150
# 163          Venezuela        17.1     28.5    4.91     17.6   16500
# 103           Mongolia        26.1     46.7    5.44     56.7    7710
# 149        Timor-Leste        62.6      2.2    9.12     27.8    1850
# 49   Equatorial Guinea       111.0     85.8    4.48     58.9   33700
#
#      inflation  life_expec  total_fer   gdpp  h_cluster
# 113      104.0        60.5       5.84   2330          1
# 163       45.9        75.4       2.47  13500          1
# 103       39.2        66.2       2.64   2650          1
# 149       26.5        71.1       6.23   3600          1
# 49        24.9        60.9       5.21  17100          1

# %%
hierarchy_result.sort_values(by=['exports'], ascending=False).head(5)
# Out:
#         country  child_mort  exports  health  imports  income  inflation  \
# 133   Singapore         2.8    200.0    3.96    174.0   72100     -0.046
# 91   Luxembourg         2.8    175.0    7.77    142.0   91700      3.620
# 98        Malta         6.8    153.0    8.65    154.0   28300      3.830
# 73      Ireland         4.2    103.0    9.19     86.5   45700     -3.220
# 131  Seychelles        14.4     93.8    3.40    108.0   20400     -4.210
#
#      life_expec  total_fer    gdpp  h_cluster
# 133        82.7       1.15   46600          2
# 91         81.3       1.63  105000          2
# 98         80.3       1.36   21100          2
# 73         80.4       2.05   48700          2
# 131        73.4       2.17   10800          1

# %%
hierarchy_result.sort_values(by=['imports'], ascending=False).head(5)
# Out:
#         country  child_mort  exports  health  imports  income  inflation  \
# 133   Singapore         2.8    200.0    3.96    174.0   72100     -0.046
# 98        Malta         6.8    153.0    8.65    154.0   28300      3.830
# 91   Luxembourg         2.8    175.0    7.77    142.0   91700      3.620
# 131  Seychelles        14.4     93.8    3.40    108.0   20400     -4.210
# 87      Lesotho        99.7     39.4   11.10    101.0    2380      4.150
#
#      life_expec  total_fer    gdpp  h_cluster
# 133        82.7       1.15   46600          2
# 98         80.3       1.36   21100          2
# 91         81.3       1.63  105000          2
# 131        73.4       2.17   10800          1
# 87         46.5       3.30    1170          1

# %% [markdown]
# ## 3.2 K-Means

# %% [markdown]
# ### 3.2.1 判斷群數
#
# #### 1. 手肘法則（ElbowMethod）

# %%
# Elbow curve method to find the ideal number of clusters.
clusters=list(range(2,8)) # 跑2~8群
ssd = []
for num_clusters in clusters:
    model_clus = KMeans(n_clusters = num_clusters, max_iter=150,random_state= 50) # 跑上限150次
    model_clus.fit(data_scaled)
    ssd.append(model_clus.inertia_)

plt.plot(clusters, ssd);

# %% [markdown]
# #### 2. 輪廓係數法（Silhouette Coefficient）
# 「找出相同群凝聚度越小、不同群分離度越高」的值
# * 凝聚度（a）是指與相同群內的其他點的平均距離。
# * 分離度（b）是指與不同群的其他點的平均距離。
#
# * 輪廓的取值範圍為[-1, +1]，越接近1表示聚類效果越好，越接近-1表示聚類效果越差；如果輪廓近似為0，則說明該樣本在兩個群的邊界上。

# %%
from sklearn.metrics import silhouette_score

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7, 8] # 跑2~8群

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=150,random_state= 50) #參數設置要跟手肘法一樣才能做比對
    kmeans.fit(data_scaled)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(data_scaled, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))

    # 越接近1越好，取6群，但分6群太瑣碎，可取3群
# Out:
# For n_clusters=2, the silhouette score is 0.2662961111870726
# For n_clusters=3, the silhouette score is 0.28329575683463126
# For n_clusters=4, the silhouette score is 0.2819090393827442
# For n_clusters=5, the silhouette score is 0.30699712235248094
# For n_clusters=6, the silhouette score is 0.3133485435540301
# For n_clusters=7, the silhouette score is 0.24325950330001792
# For n_clusters=8, the silhouette score is 0.24787966329039768

# %% [markdown]
# 選6群 (silhouette score越大越好)

# %% [markdown]
# ### 3.2.2 K-Means Modeling

# %%
cluster = KMeans(n_clusters = 3, random_state = 111)
cluster.fit(data_scaled)
# Out:
# KMeans(n_clusters=3, random_state=111)

# %%
#count number of records in every cluster
pd.Series(cluster.labels_).value_counts()
# Out:
# 0    84
# 1    47
# 2    36
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2.3 K-Means result analysis
# ### <span style="color:#3498DB">Question: 請分析各群結果</span>

# %%
pred = pd.DataFrame(cluster.labels_, columns=['k_cluster'])
kmeans_result = pd.concat([df.reset_index(drop=True), pred], axis=1)
kmeans_result
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  k_cluster
# 0         9.44        56.2       5.82    553          1
# 1         4.49        76.3       1.65   4090          0
# 2        16.10        76.5       2.89   4460          0
# 3        22.40        60.1       6.16   3530          1
# 4         1.44        76.8       2.13  12200          0
# ..         ...         ...        ...    ...        ...
# 162       2.62        63.0       3.50   2970          0
# 163      45.90        75.4       2.47  13500          0
# 164      12.10        73.1       1.95   1310          0
# 165      23.60        67.5       4.67   1310          1
# 166      14.00        52.0       5.40   1460          1
#
# [167 rows x 11 columns]

# %%
kmeans_result[['child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp', 'k_cluster']].groupby(['k_clauster'], as_index=True).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 kmeans_result[['child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp', 'k_cluster']].groupby(['k_clauster'], as_index=True).mean()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'k_clauster'

# %%
kmeans_result[['child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp', 'k_cluster']].groupby(['k_cluster'], as_index=True).mean()
# Out:
#            child_mort    exports    health    imports        income  \
# k_cluster
# 0           21.927381  40.243917  6.200952  47.473404  12305.595238
# 1           92.961702  29.151277  6.388511  42.323404   3942.404255
# 2            5.000000  58.738889  8.807778  51.491667  45672.222222
#
#            inflation  life_expec  total_fer          gdpp
# k_cluster
# 0           7.600905   72.814286   2.307500   6486.452381
# 1          12.019681   59.187234   5.008085   1922.382979
# 2           2.671250   80.127778   1.752778  42494.444444

# %% [markdown]
# * Child Mortality Rate : 每 1000 名活產中 5 歲以下兒童死亡人數
# * Fertility Rate: 在當前年齡-生育率保持不變的情況下，每位女性將生育的孩子數量
# * Life Expectancy: 如果當前的死亡率模式保持不變，新生兒的平均壽命
# * Health : Health總支出佔 GDP 總額的百分比
# * gdpp : 總 GDP 除以總人口
# * income：人均淨收入
# * Inflation(通膨): The measurement of the annual growth rate of the Total GDP
# * Exports: Exports of goods and services. 以佔總 GDP 的百分比表示
# * Imports: Imports of goods and services. 以佔總 GDP 的百分比表示
